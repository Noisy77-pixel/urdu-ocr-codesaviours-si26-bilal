# %% [markdown]
# <a href="https://colab.research.google.com/github/Noisy77-pixel/urdu-ocr-codesaviours-si26-bilal/blob/main/SI26_Week1_Bilal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install Pillow arabic-reshaper python-bidi
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.2/296.2 kB 11.6 MB/s eta 0:00:00
# ...

# %%
from PIL import Image, ImageDraw, ImageFont
import arabic_reshaper
from bidi.algorithm import get_display
import os

# 20 sample Urdu sentences for synthetic image generation
urdu_texts = [
    "\u067e\u0627\u06a9\u0633\u062a\u0627\u0646 \u0632\u0646\u062f\u06c1 \u0628\u0627\u062f",
    "\u0622\u062c \u06a9\u0627 \u0645\u0648\u0633\u0645 \u062e\u0648\u0634\u06af\u0648\u0627\u0631 \u06c1\u06d2",
    "\u062a\u0639\u0644\u06cc\u0645 \u06c1\u0631 \u0627\u0646\u0633\u0627\u0646 \u06a9\u0627 \u062d\u0642 \u06c1\u06d2",
    "\u06a9\u0631\u0627\u0686\u06cc \u067e\u0627\u06a9\u0633\u062a\u0627\u0646 \u06a9\u0627 \u0633\u0628 \u0633\u06d2 \u0628\u0691\u0627 \u0634\u06c1\u0631 \u06c1\u06d2",
    "\u0645\u062d\u0646\u062a \u06a9\u0627\u0645\u06cc\u0627\u0628\u06cc \u06a9\u06cc \u06a9\u0646\u062c\u06cc \u06c1\u06d2",
    "\u0639\u0644\u0645 \u0627\u06cc\u06a9 \u0637\u0627\u0642\u062a \u06c1\u06d2",
    "\u0635\u0628\u0631 \u06a9\u0627 \u067e\u06be\u0644 \u0645\u06cc\u0679\u06be\u0627 \u06c1\u0648\u062a\u0627 \u06c1\u06d2",
    "\u067e\u0627\u06a9\u0633\u062a\u0627\u0646 \u06a9\u0627 \u0642\u0648\u0645\u06cc \u06a9\u06be\u06cc\u0644 \u06c1\u0627\u06a9\u06cc \u06c1\u06d2",
    "\u0627\u0633\u0644\u0627\u0645 \u0622\u0628\u0627\u062f \u067e\u0627\u06a9\u0633\u062a\u0627\u0646 \u06a9\u0627 \u062f\u0627\u0631\u0627\u0644\u062d\u06a9\u0648\u0645\u062a \u06c1\u06d2",
    "\u067e\u0627\u0646\u06cc \u0632\u0646\u062f\u06af\u06cc \u06c1\u06d2",
    "\u06a9\u062a\u0627\u0628 \u0627\u0646\u0633\u0627\u0646 \u06a9\u06cc \u0628\u06c1\u062a\u0631\u06cc\u0646 \u062f\u0648\u0633\u062a \u06c1\u06d2",
    "\u0639\u06cc\u062f \u0645\u0628\u0627\u0631\u06a9",
    "\u062c\u0645\u0639\u06c1 \u0645\u0628\u0627\u0631\u06a9",
    "\u0627\u0644\u0644\u06c1 \u0627\u06a9\u0628\u0631",
    "\u0646\u06cc\u06a9\u06cc \u06a9\u0631 \u062f\u0631\u06cc\u0627 \u0645\u06cc\u06ba \u0688\u0627\u0644",
    "\u0648\u0642\u062a \u0628\u06c1\u062a \u0642\u06cc\u0645\u062a\u06cc \u06c1\u06d2",
    "\u0635\u062d\u062a \u0628\u06c1\u062a \u0628\u0691\u06cc \u0646\u0639\u0645\u062a \u06c1\u06d2",
    "\u0645\u0627\u062f\u0631 \u0648\u0637\u0646 \u0633\u06d2 \u0645\u062d\u0628\u062a",
    "\u0627\u062a\u062d\u0627\u062f \u062a\u0646\u0638\u06cc\u0645 \u06cc\u0642\u06cc\u0646 \u0645\u062d\u06a9\u0645",
    "\u0633\u0686\u0627\u0626\u06cc \u06a9\u06cc \u06c1\u0645\u06cc\u0634\u06c1 \u062c\u06cc\u062a \u06c1\u0648\u062a\u06cc \u06c1\u06d2",
]

os.makedirs('data/synthetic', exist_ok=True)

for i, text in enumerate(urdu_texts):
    reshaped = arabic_reshaper.reshape(text)
    bidi_text = get_display(reshaped)
    img = Image.new('RGB', (400, 80), color='white')
    draw = ImageDraw.Draw(img)
    draw.text((10, 20), bidi_text, fill='black')
    img.save(f'data/synthetic/urdu_{i+1}.png')
    print(f'Generated: urdu_{i+1}.png -- {text}')

print(f'\nDone! Generated {len(urdu_texts)} synthetic images in data/synthetic/')
# Out:
# Generated: urdu_1.png -- پاکستان زندہ باد
# Generated: urdu_2.png -- آج کا موسم خوشگوار ہے
# Generated: urdu_3.png -- تعلیم ہر انسان کا حق ہے
# Generated: urdu_4.png -- کراچی پاکستان کا سب سے بڑا شہر ہے
# Generated: urdu_5.png -- محنت کامیابی کی کنجی ہے
# Generated: urdu_6.png -- علم ایک طاقت ہے
# Generated: urdu_7.png -- صبر کا پھل میٹھا ہوتا ہے
# Generated: urdu_8.png -- پاکستان کا قومی کھیل ہاکی ہے
# Generated: urdu_9.png -- اسلام آباد پاکستان کا دارالحکومت ہے
# Generated: urdu_10.png -- پانی زندگی ہے
# Generated: urdu_11.png -- کتاب انسان کی بہترین دوست ہے
# Generated: urdu_12.png -- عید مبارک
# Generated: urdu_13.png -- جمعہ مبارک
# Generated: urdu_14.png -- اللہ اکبر
# Generated: urdu_15.png -- نیکی کر دریا میں ڈال
# Generated: urdu_16.png -- وقت بہت قیمتی ہے
# Generated: urdu_17.png -- صحت بہت بڑی نعمت ہے
# Generated: urdu_18.png -- مادر وطن سے محبت
# Generated: urdu_19.png -- اتحاد تنظیم یقین محکم
# Generated: urdu_20.png -- سچائی کی ہمیشہ جیت ہوتی ہے
#
# ...

# %%
import os

folders = [
    'data/raw/newspaper',
    'data/raw/books',
    'data/raw/signboards',
    'data/raw/synthetic',
    'data/raw/other',
]

for folder in folders:
    os.makedirs(folder, exist_ok=True)
    print(f'Created: {folder}')

print('\nFolder structure ready!')
print('\nTODO: Upload your collected images into the correct folders:')
print('  - data/raw/newspaper/   → photos/screenshots of Urdu newspapers')
print('  - data/raw/books/       → photos of Urdu book pages')
print('  - data/raw/signboards/  → photos of Urdu signboards')
print('  - data/raw/synthetic/   → generated Urdu text images')
print('  - data/raw/other/       → WhatsApp screenshots, other sources')
print('\nAim for at least 20 images per folder — 100 total minimum.')
# Out:
# Created: data/raw/newspaper
# Created: data/raw/books
# Created: data/raw/signboards
# Created: data/raw/synthetic
# Created: data/raw/other
#
# Folder structure ready!
#
# TODO: Upload your collected images into the correct folders:
#   - data/raw/newspaper/   → photos/screenshots of Urdu newspapers
#   - data/raw/books/       → photos of Urdu book pages
#   - data/raw/signboards/  → photos of Urdu signboards
#   - data/raw/synthetic/   → generated Urdu text images
#   - data/raw/other/       → WhatsApp screenshots, other sources
#
# Aim for at least 20 images per folder — 100 total minimum.

# %%
import csv
import glob
import os
labels = []
# --- Source 3: 20 Synthetic images (generated in Cell 2) ---
for i, text in enumerate(urdu_texts):
    labels.append({'image': f'data/synthetic/urdu_{i+1}.png', 'text': text})
# --- Source 2: 31 News screenshots (BBC Urdu, Jang, Dawn Urdu) ---
screenshot_labels = [
    ('news_screenshot_001.png', 'ایران کی امریکی حملوں میں 50 افراد کی ہلاکت کی تصدیق'),
    ('news_screenshot_002.png', 'فیچر اور تجزیے'),
    ('news_screenshot_003.png', 'پاکستان میں ڈیزل 31.05 اور پٹرول 5.44 روپے مہنگا'),
    ('news_screenshot_004.png', 'پاکستان کے خلاف 365 رنز کی ناقابل شکست اننگز'),
    ('news_screenshot_005.png', 'زیارت حملے کے خلاف دھرنا ختم'),
    ('news_screenshot_006.png', 'بی بی سی اردو اب واٹس ایپ پر'),
    ('news_screenshot_007.png', 'سبسکرائب کرنے کے لیے کلک کریں'),
    ('news_screenshot_008.png', 'روزنامہ جنگ'),
    ('news_screenshot_009.png', 'تازہ ترین خبریں'),
    ('news_screenshot_010.png', 'پاکستان کی خبریں'),
    ('news_screenshot_011.png', 'کھیل کی خبریں'),
    ('news_screenshot_012.png', 'عالمی خبریں'),
    ('news_screenshot_013.png', 'تعلیم اور صحت'),
    ('news_screenshot_014.png', 'سائنس اور ٹیکنالوجی'),
    ('news_screenshot_015.png', 'ایران امریکہ کشیدگی'),
    ('news_screenshot_016.png', 'کراچی کی تازہ خبریں'),
    ('news_screenshot_017.png', 'اسلام آباد کی خبریں'),
    ('news_screenshot_018.png', 'لاہور کی تازہ ترین خبریں'),
    ('news_screenshot_019.png', 'انڈیا میں 20 روز سے بھوک ہڑتال'),
    ('news_screenshot_020.png', 'امریکی حملوں کے بعد ایران کے مختلف علاقوں سے دھماکوں کی اطلاعات'),
    ('news_screenshot_021.png', 'قیوم خان ملنگ پاکستان سے ملحقہ افغان صوبے میں'),
    ('news_screenshot_022.png', 'ورلڈ کپ فائنل میں سپین کی فتح'),
    ('news_screenshot_023.png', 'لارڈز میں رنز کی برسات انگلینڈ کا ریکارڈ ٹوٹل'),
    ('news_screenshot_024.png', 'عوامی ایکشن کمیٹی کے بارے میں سوال نہ کریں'),
    ('news_screenshot_025.png', 'انٹرویو کا ویڈیو کلپ وائرل ہونے کے بعد'),
    ('news_screenshot_026.png', 'موقف سلطنت ایئر بیس ایرانی حملوں کا نشانہ'),
    ('news_screenshot_027.png', 'پاکستان میں غیر قانونی طور پر مقیم افغان پناہ گزینوں کی بیدخلی'),
    ('news_screenshot_028.png', 'سعودی عرب میں گیس سلنڈر دھماکے میں ہلاک ہونے والے پانچ پاکستانی دوست'),
    ('news_screenshot_029.png', 'انڈین خلائی ادارے کے سائنسدان استعفے کیوں دے رہے ہیں'),
    ('news_screenshot_030.png', 'مراکش تیونس اور ترکی ایران امریکہ جنگ کی وجہ سے کن ممالک میں سیاحت سستی ہوئی'),
    ('news_screenshot_031.png', 'فٹ بال ورلڈ کپ فائنل یمال کے عروج اور میسی کے ممکنہ الوداع کی کہانی'),
]
for fname, text in screenshot_labels:
    labels.append({'image': f'data/raw/newspaper/{fname}', 'text': text})
# --- Source 1: 49 RAVI dataset character images (to reach 100 total) ---
ravi_char_labels = [
    ('ravi_001.png', 'ء'), ('ravi_002.png', 'ء'), ('ravi_003.png', 'ء'),
    ('ravi_004.png', 'آ'), ('ravi_005.png', 'آ'), ('ravi_006.png', 'آ'),
    ('ravi_007.png', 'ا'), ('ravi_008.png', 'ا'), ('ravi_009.png', 'ا'),
    ('ravi_010.png', 'ب'), ('ravi_011.png', 'ب'), ('ravi_012.png', 'ب'),
    ('ravi_013.png', 'ت'), ('ravi_014.png', 'ت'), ('ravi_015.png', 'ت'),
    ('ravi_016.png', 'ث'), ('ravi_017.png', 'ث'), ('ravi_018.png', 'ث'),
    ('ravi_019.png', 'ج'), ('ravi_020.png', 'ج'), ('ravi_021.png', 'ج'),
    ('ravi_022.png', 'ح'), ('ravi_023.png', 'ح'), ('ravi_024.png', 'ح'),
    ('ravi_025.png', 'خ'), ('ravi_026.png', 'خ'), ('ravi_027.png', 'خ'),
    ('ravi_028.png', 'د'), ('ravi_029.png', 'د'), ('ravi_030.png', 'د'),
    ('ravi_031.png', 'ذ'), ('ravi_032.png', 'ذ'), ('ravi_033.png', 'ذ'),
    ('ravi_034.png', 'ر'), ('ravi_035.png', 'ر'), ('ravi_036.png', 'ر'),
    ('ravi_037.png', 'ز'), ('ravi_038.png', 'ز'), ('ravi_039.png', 'ز'),
    ('ravi_040.png', 'س'), ('ravi_041.png', 'س'), ('ravi_042.png', 'س'),
    ('ravi_043.png', 'ش'), ('ravi_044.png', 'ش'), ('ravi_045.png', 'ش'),
    ('ravi_046.png', 'ص'), ('ravi_047.png', 'ص'), ('ravi_048.png', 'ص'),
    ('ravi_049.png', 'ض'),
]
for fname, text in ravi_char_labels:
    labels.append({'image': f'data/raw/other/{fname}', 'text': text})
# --- Write labels.csv ---
with open('data/labels.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.DictWriter(f, fieldnames=['image', 'text'])
    writer.writeheader()
    writer.writerows(labels)
print(f'Labels file created with {len(labels)} entries')
print(f'  - Synthetic images:  20')
print(f'  - News screenshots:  31')
print(f'  - RAVI characters:   49')
print(f'  - TOTAL:             {len(labels)}')
print(f'\nFile saved: data/labels.csv')
# Out:
# Labels file created with 100 entries
#   - Synthetic images:  20
#   - News screenshots:  31
#   - RAVI characters:   49
#   - TOTAL:             100
#
# File saved: data/labels.csv
